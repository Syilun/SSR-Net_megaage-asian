# %% [markdown]
# <a href="https://colab.research.google.com/github/Syilun/SSR-Net_megaage-asian/blob/master/SSR_Net_megaage_asian_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Syilun/-SSR-Net_megaage-asian_v1.git
# Out:
# Cloning into '-SSR-Net_megaage-asian_v1'...
# remote: Enumerating objects: 98, done.
# remote: Total 98 (delta 0), reused 0 (delta 0), pack-reused 98
# Unpacking objects: 100% (98/98), done.

# %%
# !unzip /content/drive/My\ Drive/Megaage_asian/megaage_asian.zip -d /content/-SSR-Net_megaage-asian_v1
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/55.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/550.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5500.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5501.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5502.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5503.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5504.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5505.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5506.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5507.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5508.jpg
#   inflating: /content/-SSR-Net_megaage-asian_v1/megaage_asian/train/5509.jpg
# ...

# %%
# %cd /content/-SSR-Net_megaage-asian_v1
# !python TYY_Megaage_asian_create_db.py
# Out:
# /content/-SSR-Net_megaage-asian_v1
# 100% 40000/40000 [00:28<00:00, 1420.33it/s]

# %%
# !pip install keras_applications==1.0.4 --no-deps
# !pip install keras_applications
# !pip uninstall TensorFlow
# !pip uninstall Keras
# !pip uninstall Python

# !pip install TensorFlow==1.10.1
# !pip install Keras==2.2.4

# %%
# !apt-get install python3.5
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libpython3.5-minimal' for regex 'python3.5'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !chmod 755 /content/-SSR-Net_megaage-asian_v1/run_ssrnet_megaage.sh
# !/content/-SSR-Net_megaage-asian_v1/run_ssrnet_megaage.sh
# Out:
# Using TensorFlow backend.
# DEBUG:root:Loading training data...
# DEBUG:root:Loading testing data...
# DEBUG:root:image_dim_ordering = 'tf'
# DEBUG:root:Creating model...
# DEBUG:root:Model summary...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, array(64), ar 0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 62, 62, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 62, 62, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 62, 62, 16)   64          conv2d_5[0][0]
# ...
